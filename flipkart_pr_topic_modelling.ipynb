# %% [markdown]
# # Flipkart Customer Reviews
#
# Dataset Source: [Kaggle](https://www.kaggle.com/datasets/niraliivaghani/flipkart-product-customer-reviews-dataset)
#
# ## <b>Topic Modelling</b>
#
# ### <b><i>Using BERTopic (with spacy model 'en_core_web_sm' for embedding)</i></b>
#
# <br><br><br>

# %% [markdown]
# ## Libraries and Data

# %%
# import locale
# locale.getpreferredencoding = lambda: "UTF-8"

# !pip install bertopic
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bertopic
#   Downloading bertopic-0.14.1-py2.py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.7/120.7 KB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.9/dist-packages (from bertopic) (5.13.1)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.4.4)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.9/dist-packages (from bertopic) (4.65.0)
# Collecting umap-learn>=0.5.0
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 KB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.22.4)
# Collecting sentence-transformers>=0.4.1
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 KB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting hdbscan>=0.8.29
#   Downloading hdbscan-0.8.29.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 40.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (0.29.33)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (1.1.1)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (1.10.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->bertopic) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=4.7.0->bertopic) (8.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.1.0)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.27.3-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 58.9 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (1.13.1+cu116)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.14.1+cu116)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 48.7 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.13.3-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 20.4 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.9/dist-packages (from umap-learn>=0.5.0->bertopic) (0.56.4)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.8.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 47.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.27.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.10.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (67.6.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.39.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 76.8 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (8.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2022.12.7)
# Building wheels for collected packages: hdbscan, sentence-transformers, umap-learn, pynndescent
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.29-cp39-cp39-linux_x86_64.whl size=3582106 sha256=950eced4c1e2cf25b5a97dbe7d2aa53fc954087abb0c7de59d608ed1fff6ff19
#   Stored in directory: /root/.cache/pip/wheels/05/6f/88/1a4c04276b98306f00217a1e300e6ba0252c6aa4f7616067ae
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125942 sha256=b73ac99229fc1692e703ef1be5ae357a3c08236a180605a98f6926acf970a3e7
#   Stored in directory: /root/.cache/pip/wheels/71/67/06/162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82830 sha256=af95ae400240b2f043903aac380f84711494834e8d2b37647ab01013a8461e23
#   Stored in directory: /root/.cache/pip/wheels/f4/3e/1c/596d0a463d17475af648688443fa4846fef624d1390339e7e9
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.8-py3-none-any.whl size=55509 sha256=28e20edc4a0426c5eafcfeb76b3500e269eb3c7d24b2acbfdebacfa2f89b9ad9
#   Stored in directory: /root/.cache/pip/wheels/b9/89/cc/59ab91ef5b21dc2ab3635528d7d227f49dfc9169905dcb959d
# Successfully built hdbscan sentence-transformers umap-learn pynndescent
# Installing collected packages: tokenizers, sentencepiece, huggingface-hub, transformers, pynndescent, hdbscan, umap-learn, sentence-transformers, bertopic
# Successfully installed bertopic-0.14.1 hdbscan-0.8.29 huggingface-hub-0.13.3 pynndescent-0.5.8 sentence-transformers-2.2.2 sentencepiece-0.1.97 tokenizers-0.13.2 transformers-4.27.3 umap-learn-0.5.3

# %%
import pandas as pd
import spacy
from bertopic import BERTopic


import re
import nltk.corpus
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Flipkart Product Reviews - Kaggle/Dataset-SA.csv')
data['sentiment_code'] = pd.Categorical(data.Sentiment).codes
data['sentiment_code'] = data['sentiment_code'].astype('Int64')
data.dropna(inplace = True)

# %%
print(data.product_name.nunique())
data.product_name.value_counts()
# Out:
# 841
# cello Pack of 18 Opalware Cello Dazzle Lush Fiesta Opalware Dinner Set, 18 Pieces Dinner SetÃÂ ÃÂ (White, Microwave Safe)                                                               6005
# Lakm?? Eyeconic Kajal Twin Pack??????????(Deep Black, 0.7 g)                                                                                                                              5000
# Mi 5A 80 cm (32 inch) HD Ready LED Smart Android TV with Dolby Audio (2022 Model)                                                                                                         2205
# cello Pack of 18 Opalware Cello Dazzle Lush Fiesta Opalware Dinner Set 18 Pieces Dinner SetWhite Microwave Safe                                                                           2095
# Home Sizzler 153 cm 502 ft Polyester Room Darkening Window Curtain Pack Of 2Floral Brown                                                                                                  2012
#                                                                                                                                                                                           ...
# LS2727 Avatar Day and Date Functioning Crocodile Strap Analog Analog Watch   For Men                                                                                                         8
# mobspy 3.5mm Clip Microphone For Youtube | Collar Mic for Voice Recording | Lapel Mic Mobile, PC, Laptop, Android Smartphones, DSLR Camera Microphone Microphone collar micÂ Â (Black)       7
# LA VERNE Self Design Double Mink Blanket for  Heavy WinterWoollen Blend Pink                                                                                                                 5
# Stylish Brown Sports Men Watches Multifunctional Luxury Waterproof Modern Digital Watch   For Men                                                                                            5
# LS2917 Mesh Strap All Black Avatar Day and Date Functioning Quartz Analog Watch   For Men                                                                                                    2
# Name: product_name, Length: 841, dtype: int64

# %% [markdown]
# ## Pre-process Text

# %%
# define function to clean text

stop = stopwords.words('english')
add_stopwords = ['aqua', 'black', 'blue', 'fuchsia', 'gray', 'green', 'lime', 'maroon', 'navy', 'olive', 'purple', 'red', 'silver', 'teal', 'white', 'yellow', 'pack', 'light']
stop.extend(add_stopwords)

lemmatizer = WordNetLemmatizer()


def clean_text(text):

  text = text.lower()
  text = re.sub(r"(@\[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", text) # Punctuations, URLs and @
  text = " ".join([word for word in text.split() if word not in (stop)]) # Stopwords
  text = " ".join([lemmatizer.lemmatize(word) for word in text.split()]) # Stemming
  
  return(text)

# %%
data_sub = data[['product_name', 'Summary']].copy(deep = True)
data_sub = data_sub.applymap(clean_text)
data_sub
# Out:
#                                              product_name  \
# 0       candes 12 l roompersonal air coolerwhite elega...
# 1       candes 12 l roompersonal air coolerwhite elega...
# 2       candes 12 l roompersonal air coolerwhite elega...
# 3       candes 12 l roompersonal air coolerwhite elega...
# 4       candes 12 l roompersonal air coolerwhite elega...
# ...                                                   ...
# 205047  cello 18 opalware cello dazzle lush fiesta opa...
# 205048  cello 18 opalware cello dazzle lush fiesta opa...
# 205049  cello 18 opalware cello dazzle lush fiesta opa...
# 205050  cello 18 opalware cello dazzle lush fiesta opa...
# 205051  cello 18 opalware cello dazzle lush fiesta opa...
#
#                                                   Summary
# 0       great cooler excellent air flow price amazing ...
# 1                   best budget 2 fit cooler nice cooling
# 2                           quality good power air decent
# 3                                         bad product fan
# 4                                           ok ok product
# ...                                                   ...
# 205047                                       good product
# 205048                                               nice
# 205049                                 nice fast delivery
# 205050                                    awesome product
# 205051  good mixing bowl included one disappointmentan...
#
# [180379 rows x 2 columns]

# %% [markdown]
# ## Topic Modelling

# %%
# Topic modelling based on product name text

docs_product_name = data_sub.product_name
nlp = spacy.load('en_core_web_sm', exclude=['tagger', 'parser', 'ner', 'attribute_ruler', 'lemmatizer'])

topic_model_product_name = BERTopic(embedding_model=nlp, nr_topics=50)
topics, probs = topic_model_product_name.fit_transform(docs_product_name)

fig = topic_model_product_name.visualize_topics()
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="2d88c4f0-2d21-4805-a857-9e2d1baf7a09" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d88c4f0-2d21-4805-a857-9e2d1baf7a09")) {                    Plotly.newPlot(                        "2d88c4f0-2d21-4805-a857-9e2d1baf7a09",                        [{"customdata":[[0,"cello | dinner | opalware | 18 | set",125344],[1,"lakm | eyeconic | twin | kajal | packdeep",23461],[2,"stripe | microfibre | la | verne | skewer",5187],[3,"kettle15 | favourite | pigeon | electric | avum",2515],[4,"doms | pencil | kit | smart | kjr32",2271],[5,"cartridge | ink | hp | 680 | 28",2059],[6,"holder | mobile | tanunni | susi | pill",1346],[7,"swimming | shaping | lcs8188 | mop | florence",1253],[8,"roam2 | mono | speakerblack | freshener150 | otoroys",1222],[9,"hot | treehybrid | global | dragon | magical",850],[10,"gx1 | 500 | mixer | grinder | bajaj",682],[11,"lengthpack | ankle | striped | woman | men",620],[12,"midcalfcrewpack | solid | men |  | ",593],[13,"sujata | juicer | imperial | slow | 240",574],[14,"craftify | rodwater | heater | immersion | high",549],[15,"pwg | prestige | grinderblack | wet | tricolor",531],[16,"650 | inalsa | lx | processorwhite | food",498],[17,"tw0tg7304 | pg47 | catridge | watch | analog",477],[18,"ro | purifierblack | advanced | pureit | mf",419],[19,"acm2aa | purifierwhite | portable | room | air",406],[20,"x515jaej392ws | x515jaej362ws | vivobook | i3 | 180",334],[21,"ovenms2043db | lg | solo | 20 | microwave",296],[22,"etmax | nano | stereo | 30 | theatreblack",282],[23,"embroco | fibre | lurags | bailsbrown | 5white",281],[24,"organizersred | jewelery | plastic | susi | rsv",280],[25,"chromecastblack | built | stick | shyokand | sofafinish",259],[26,"devicesblack | miredmixiomi | 18w | quick | charger",238],[27,"grinderpurple | ultra | wet | grind | 20",227],[28,"1170blbr | unique | new | date | day",218],[29,"1000 | processorsilverblack | overseas | chawla | carpet152",200],[30,"tw00zr347 | watch | analog | men | ",200],[31,"kick | cosco | football | 5pack | size",197],[32,"hill | fansmoked | deco | briz | crompton",182],[33,"ovenms23a301tak | 23 | solo | samsung | microwave",171],[34,"4k | blackblack | stick | realme | google",148],[35,"lampbrown | dzire | pendant | ceiling | ",100],[36,"gk320 | keyboardblack | wired | usb | hp",100],[37,"shelf6rack | book | cmerchants | shelffinish | open",100],[38,"stroke | art | doms | kit | ",100],[39,"pg | 745s | cartridge | canon | ink",100],[40,"carpet136 | 180 | rectangle | cm | smartbuy",84],[41,"bsap490lan | purifierwhite | portable | room | air",61],[42,"poowerest | carbon | wardrobefinish | collapsible | steel",53],[43,"lectose | assembled | pre | laptop | tablefinish",46],[44,"ponmani | grinderred | tilting | wet | power",40],[45,"wg905 | preethi | grinderpurple | wet | ",29],[46,"1000 | processorblacksilver | inalsa | inox | food",26],[47,"staranddaisy | tablefinish | acnos | pink | plastic",21],[48,"denicraas | lampblack | pendant | ceiling | cherry",13]],"hovertemplate":"<b>Topic %{customdata[0]}</b><br>%{customdata[1]}<br>Size: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[125344,23461,5187,2515,2271,2059,1346,1253,1222,850,682,620,593,574,549,531,498,477,419,406,334,296,282,281,280,259,238,227,218,200,200,197,182,171,148,100,100,100,100,100,84,61,53,46,40,29,26,21,13],"sizemode":"area","sizeref":78.34,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-5.040951251983643,-5.153820514678955,0.7947749495506287,4.55914831161499,10.451571464538574,3.0999813079833984,2.7237956523895264,1.621797800064087,0.5866164565086365,7.948272228240967,3.1919283866882324,1.81837344 ...

# %%
# Topic modelling based on Summary text

docs_Summary = data_sub.Summary
# nlp = spacy.load('en_core_web_sm', exclude=['tagger', 'parser', 'ner', 'attribute_ruler', 'lemmatizer'])

topic_model_Summary = BERTopic(embedding_model=nlp, nr_topics=20)
topics, probs = topic_model_Summary.fit_transform(docs_Summary)

fig = topic_model_Summary.visualize_topics()
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="dc4cd8d1-2f92-464e-8a7f-9f10dc301992" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc4cd8d1-2f92-464e-8a7f-9f10dc301992")) {                    Plotly.newPlot(                        "dc4cd8d1-2f92-464e-8a7f-9f10dc301992",                        [{"customdata":[[0,"good | nice | product | quality | bad",109607],[1,"super | gd | product | se | upar",3658],[2,"osm | loved | expected | satisfied | liked",3254],[3,"really | ever | simply | properly | highly",1541],[4,"thanks | flipkart | kajal | god | nice",891],[5,"wow | okay | well | yes | super",682],[6,"must | buy | could | product | better",656],[7,"nyc | kit | product | okey | noisey",473],[8,"nic | wrost | product | drs | thaks",166],[9," |  |  |  | ",44],[10,"enough | fast | good | material | name",37],[11,"goog | speed | good |  | ",33],[12,"okk |  |  |  | ",31],[13,"isnt | wasnt | working | cable | werent",30],[14,"luck | good | itame |  | ",28],[15,"osam |  |  |  | ",27],[16,"thats | amazing | working | really | good",21],[17,"cute |  |  |  | ",18],[18,"duper | super | cleaner | cooler | ",11]],"hovertemplate":"<b>Topic %{customdata[0]}</b><br>%{customdata[1]}<br>Size: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[109607,3658,3254,1541,891,682,656,473,166,44,37,33,31,30,28,27,21,18,11],"sizemode":"area","sizeref":68.504375,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[5.358857154846191,14.459517478942871,6.231080055236816,6.289055347442627,6.73897123336792,7.379483699798584,6.601871490478516,1.121599793434143,0.9007436037063599,null,-9.659626960754395,-9.453886985778809,5.730343341827393,-10.412176132202148,-9.93036937713623,5.885901927947998,-10.114656448364258,7.695644378662109,14.546550750732422],"xaxis":"x","y":[4.252893447875977,-8.538359642028809,4.792416572570801,4.15031099319458,3.4846513271331787,3.5778510570526123,3.851947069168091,-9.294146537780762,-9.51494026184082,null,1.8498802185058594,2.2523281574249268,4.9645843505859375,1.5483478307724,2.122115135192871,4.699132919311523,1.5424902439117432,3.4274728298187256,-8.626788139343262],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333 ...
